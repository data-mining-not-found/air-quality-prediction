# %%
import requests
import os
import time
import datetime

# %%
def retrieve_data(dataType, city):
    """
    Retrieve live data and save it in folders
    
    params: dataType: string, options: ['meteorology', 'airquality', 'grid']
    params: city: string, options: ['beijing', 'london']
    return: None
    """
    cityAbbr = 'bj' if city == 'beijing' else 'ld'
    
    # Create directories for each city
    path = '../raw_data/{}'.format(city)
    if not os.path.isdir(path):
        os.makedirs(path)

    # Create directories for each kind of data
    path = '../raw_data/{0}/{1}'.format(city, dataType)
    if not os.path.isdir(path):
        os.makedirs(path)

    # Initialize date variables
    utcTime = datetime.datetime.utcnow()
    utcToday = datetime.date(year=utcTime.year, month=utcTime.month, day=utcTime.day)

    # Retrieve data day by day, from 2018/03/31 until now
    currentDate = datetime.date(year=2018, month=3, day=31)
    while currentDate <= utcToday:
        filename = '{0}_{1}_{2:%Y}{2:%m}{2:%d}.csv'.format(cityAbbr, dataType, currentDate)
        path = '../raw_data/{0}/{1}/{2}'.format(city, dataType, filename)
        if not os.path.isfile(path) or currentDate == utcToday:
            if dataType == 'grid':
                input = '{}_{}'.format(cityAbbr, dataType)
                url = 'https://biendata.com/competition/meteorology/{0}/{1}-0/{1}-23/2k0d1d8'.format(input, currentDate)
            else:
                url = 'https://biendata.com/competition/{0}/{1}/{2}-0/{2}-23/2k0d1d8'.format(dataType, cityAbbr, currentDate)

            response = requests.get(url)
            if response.text == 'None':
                print("No data in {}".format(filename))
                pass
            else:
                with open(path, 'w') as f:
                    f.write(response.text)
                print("{}: Retrieved".format(path))

        # Set currentDate to the next day
        currentDate += datetime.timedelta(days=1)

# %%
retrieve_data('airquality', 'london')
print('Air Quality in London: Done')

retrieve_data('grid', 'london')
print('Grid Meteorology in London: Done')
# Out:
# ../raw_data/london/airquality/ld_airquality_20180331.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180401.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180402.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180403.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180404.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180405.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180406.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180407.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180408.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180409.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180410.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180411.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180412.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180413.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180414.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180415.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180416.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180417.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180418.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180419.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180420.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180421.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180422.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180423.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180424.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180425.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180426.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180427.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180428.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180429.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180430.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180501.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180502.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180503.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180504.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180505.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180506.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180507.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180508.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180509.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180510.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180511.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180512.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180513.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180514.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180515.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180516.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180517.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180518.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180519.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180520.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180521.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180522.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180523.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180524.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180525.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180526.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180527.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180528.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180529.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180530.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180531.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180601.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180602.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180603.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180604.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180605.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180606.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180607.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180608.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180609.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180610.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180611.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180612.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180613.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180614.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180615.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180616.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180617.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180618.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180619.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180620.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180621.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180622.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180623.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180624.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180625.csv: Retrieved
# ../raw_data/london/airquality/ld_airquality_20180626.csv: Retrieved
# No data in ld_airquality_20180627.csv
# No data in ld_airquality_20180628.csv
# No data in ld_airquality_20180629.csv
# No data in ld_airquality_20180630.csv
# No data in ld_airquality_20180701.csv
# No data in ld_airquality_20180702.csv
# No data in ld_airquality_20180703.csv
# No data in ld_airquality_20180704.csv
# No data in ld_airquality_20180705.csv
# No data in ld_airquality_20180706.csv
# No data in ld_airquality_20180707.csv
# No data in ld_airquality_20180708.csv
# No data in ld_airquality_20180709.csv
# No data in ld_airquality_20180710.csv
# No data in ld_airquality_20180711.csv
# No data in ld_airquality_20180712.csv
# No data in ld_airquality_20180713.csv
# No data in ld_airquality_20180714.csv
# No data in ld_airquality_20180715.csv
# No data in ld_airquality_20180716.csv
# No data in ld_airquality_20180717.csv
# No data in ld_airquality_20180718.csv
# No data in ld_airquality_20180719.csv
# No data in ld_airquality_20180720.csv
# No data in ld_airquality_20180721.csv
# No data in ld_airquality_20180722.csv
# No data in ld_airquality_20180723.csv
# No data in ld_airquality_20180724.csv
# No data in ld_airquality_20180725.csv
# No data in ld_airquality_20180726.csv
# No data in ld_airquality_20180727.csv
# No data in ld_airquality_20180728.csv
# No data in ld_airquality_20180729.csv
# No data in ld_airquality_20180730.csv
# No data in ld_airquality_20180731.csv
# No data in ld_airquality_20180801.csv
# No data in ld_airquality_20180802.csv
# No data in ld_airquality_20180803.csv
# No data in ld_airquality_20180804.csv
# No data in ld_airquality_20180805.csv
# No data in ld_airquality_20180806.csv
# No data in ld_airquality_20180807.csv
# No data in ld_airquality_20180808.csv
# No data in ld_airquality_20180809.csv
# No data in ld_airquality_20180810.csv
# No data in ld_airquality_20180811.csv
# No data in ld_airquality_20180812.csv
# No data in ld_airquality_20180813.csv
# No data in ld_airquality_20180814.csv
# No data in ld_airquality_20180815.csv
# No data in ld_airquality_20180816.csv
# No data in ld_airquality_20180817.csv
# No data in ld_airquality_20180818.csv
# No data in ld_airquality_20180819.csv
# No data in ld_airquality_20180820.csv
# No data in ld_airquality_20180821.csv
# No data in ld_airquality_20180822.csv
# No data in ld_airquality_20180823.csv
# No data in ld_airquality_20180824.csv
# No data in ld_airquality_20180825.csv
# No data in ld_airquality_20180826.csv
# No data in ld_airquality_20180827.csv
# No data in ld_airquality_20180828.csv
# No data in ld_airquality_20180829.csv
# No data in ld_airquality_20180830.csv
# No data in ld_airquality_20180831.csv
# No data in ld_airquality_20180901.csv
# No data in ld_airquality_20180902.csv
# No data in ld_airquality_20180903.csv
# No data in ld_airquality_20180904.csv
# No data in ld_airquality_20180905.csv
# No data in ld_airquality_20180906.csv
# No data in ld_airquality_20180907.csv
# No data in ld_airquality_20180908.csv
# No data in ld_airquality_20180909.csv
# No data in ld_airquality_20180910.csv
# No data in ld_airquality_20180911.csv
# No data in ld_airquality_20180912.csv
# No data in ld_airquality_20180913.csv
# No data in ld_airquality_20180914.csv
# No data in ld_airquality_20180915.csv
# No data in ld_airquality_20180916.csv
# No data in ld_airquality_20180917.csv
# No data in ld_airquality_20180918.csv
# No data in ld_airquality_20180919.csv
# No data in ld_airquality_20180920.csv
# No data in ld_airquality_20180921.csv
# No data in ld_airquality_20180922.csv
# No data in ld_airquality_20180923.csv
# No data in ld_airquality_20180924.csv
# No data in ld_airquality_20180925.csv
# No data in ld_airquality_20180926.csv
# No data in ld_airquality_20180927.csv
# No data in ld_airquality_20180928.csv
# No data in ld_airquality_20180929.csv
# No data in ld_airquality_20180930.csv
# No data in ld_airquality_20181001.csv
# No data in ld_airquality_20181002.csv
# No data in ld_airquality_20181003.csv
# No data in ld_airquality_20181004.csv
# No data in ld_airquality_20181005.csv
# No data in ld_airquality_20181006.csv
# No data in ld_airquality_20181007.csv
# No data in ld_airquality_20181008.csv
# No data in ld_airquality_20181009.csv
# No data in ld_airquality_20181010.csv
# No data in ld_airquality_20181011.csv
# No data in ld_airquality_20181012.csv
# No data in ld_airquality_20181013.csv
# No data in ld_airquality_20181014.csv
# No data in ld_airquality_20181015.csv
# No data in ld_airquality_20181016.csv
# No data in ld_airquality_20181017.csv
# No data in ld_airquality_20181018.csv
# No data in ld_airquality_20181019.csv
# No data in ld_airquality_20181020.csv
# No data in ld_airquality_20181021.csv
# No data in ld_airquality_20181022.csv
# No data in ld_airquality_20181023.csv
# No data in ld_airquality_20181024.csv
# No data in ld_airquality_20181025.csv
# No data in ld_airquality_20181026.csv
# No data in ld_airquality_20181027.csv
# No data in ld_airquality_20181028.csv
# No data in ld_airquality_20181029.csv
# No data in ld_airquality_20181030.csv
# No data in ld_airquality_20181031.csv
# No data in ld_airquality_20181101.csv
# No data in ld_airquality_20181102.csv
# No data in ld_airquality_20181103.csv
# No data in ld_airquality_20181104.csv
# No data in ld_airquality_20181105.csv
# No data in ld_airquality_20181106.csv
# No data in ld_airquality_20181107.csv
# No data in ld_airquality_20181108.csv
# No data in ld_airquality_20181109.csv
# No data in ld_airquality_20181110.csv
# No data in ld_airquality_20181111.csv
# No data in ld_airquality_20181112.csv
# No data in ld_airquality_20181113.csv
# No data in ld_airquality_20181114.csv
# No data in ld_airquality_20181115.csv
# No data in ld_airquality_20181116.csv
# No data in ld_airquality_20181117.csv
# No data in ld_airquality_20181118.csv
# No data in ld_airquality_20181119.csv
# No data in ld_airquality_20181120.csv
# No data in ld_airquality_20181121.csv
# No data in ld_airquality_20181122.csv
# No data in ld_airquality_20181123.csv
# No data in ld_airquality_20181124.csv
# No data in ld_airquality_20181125.csv
# No data in ld_airquality_20181126.csv
# No data in ld_airquality_20181127.csv
# No data in ld_airquality_20181128.csv
# No data in ld_airquality_20181129.csv
# No data in ld_airquality_20181130.csv
# No data in ld_airquality_20181201.csv
# No data in ld_airquality_20181202.csv
# No data in ld_airquality_20181203.csv
# No data in ld_airquality_20181204.csv
# No data in ld_airquality_20181205.csv
# No data in ld_airquality_20181206.csv
# No data in ld_airquality_20181207.csv
# No data in ld_airquality_20181208.csv
# No data in ld_airquality_20181209.csv
# No data in ld_airquality_20181210.csv
# No data in ld_airquality_20181211.csv
# No data in ld_airquality_20181212.csv
# No data in ld_airquality_20181213.csv
# No data in ld_airquality_20181214.csv
# No data in ld_airquality_20181215.csv
# No data in ld_airquality_20181216.csv
# No data in ld_airquality_20181217.csv
# No data in ld_airquality_20181218.csv
# No data in ld_airquality_20181219.csv
# No data in ld_airquality_20181220.csv
# No data in ld_airquality_20181221.csv
# No data in ld_airquality_20181222.csv
# No data in ld_airquality_20181223.csv
# No data in ld_airquality_20181224.csv
# No data in ld_airquality_20181225.csv
# No data in ld_airquality_20181226.csv
# No data in ld_airquality_20181227.csv
# No data in ld_airquality_20181228.csv
# No data in ld_airquality_20181229.csv
# No data in ld_airquality_20181230.csv
# No data in ld_airquality_20181231.csv
# No data in ld_airquality_20190101.csv
# No data in ld_airquality_20190102.csv
# No data in ld_airquality_20190103.csv
# No data in ld_airquality_20190104.csv
# No data in ld_airquality_20190105.csv
# No data in ld_airquality_20190106.csv
# No data in ld_airquality_20190107.csv
# No data in ld_airquality_20190108.csv
# No data in ld_airquality_20190109.csv
# No data in ld_airquality_20190110.csv
# No data in ld_airquality_20190111.csv
# No data in ld_airquality_20190112.csv
# No data in ld_airquality_20190113.csv
# No data in ld_airquality_20190114.csv
# No data in ld_airquality_20190115.csv
# No data in ld_airquality_20190116.csv
# No data in ld_airquality_20190117.csv
# No data in ld_airquality_20190118.csv
# No data in ld_airquality_20190119.csv
# No data in ld_airquality_20190120.csv
# No data in ld_airquality_20190121.csv
# No data in ld_airquality_20190122.csv
# No data in ld_airquality_20190123.csv
# No data in ld_airquality_20190124.csv
# No data in ld_airquality_20190125.csv
# No data in ld_airquality_20190126.csv
# No data in ld_airquality_20190127.csv
# No data in ld_airquality_20190128.csv
# No data in ld_airquality_20190129.csv
# No data in ld_airquality_20190130.csv
# No data in ld_airquality_20190131.csv
# No data in ld_airquality_20190201.csv
# No data in ld_airquality_20190202.csv
# No data in ld_airquality_20190203.csv
# No data in ld_airquality_20190204.csv
# No data in ld_airquality_20190205.csv
# No data in ld_airquality_20190206.csv
# No data in ld_airquality_20190207.csv
# No data in ld_airquality_20190208.csv
# No data in ld_airquality_20190209.csv
# No data in ld_airquality_20190210.csv
# No data in ld_airquality_20190211.csv
# No data in ld_airquality_20190212.csv
# No data in ld_airquality_20190213.csv
# No data in ld_airquality_20190214.csv
# No data in ld_airquality_20190215.csv
# No data in ld_airquality_20190216.csv
# No data in ld_airquality_20190217.csv
# No data in ld_airquality_20190218.csv
# No data in ld_airquality_20190219.csv
# No data in ld_airquality_20190220.csv
# No data in ld_airquality_20190221.csv
# No data in ld_airquality_20190222.csv
# No data in ld_airquality_20190223.csv
# No data in ld_airquality_20190224.csv
# No data in ld_airquality_20190225.csv
# No data in ld_airquality_20190226.csv
# No data in ld_airquality_20190227.csv
# No data in ld_airquality_20190228.csv
# No data in ld_airquality_20190301.csv
# No data in ld_airquality_20190302.csv
# No data in ld_airquality_20190303.csv
# No data in ld_airquality_20190304.csv
# No data in ld_airquality_20190305.csv
# No data in ld_airquality_20190306.csv
# No data in ld_airquality_20190307.csv
# No data in ld_airquality_20190308.csv
# No data in ld_airquality_20190309.csv
# No data in ld_airquality_20190310.csv
# No data in ld_airquality_20190311.csv
# No data in ld_airquality_20190312.csv
# No data in ld_airquality_20190313.csv
# No data in ld_airquality_20190314.csv
# No data in ld_airquality_20190315.csv
# No data in ld_airquality_20190316.csv
# No data in ld_airquality_20190317.csv
# No data in ld_airquality_20190318.csv
# No data in ld_airquality_20190319.csv
# No data in ld_airquality_20190320.csv
# No data in ld_airquality_20190321.csv
# No data in ld_airquality_20190322.csv
# No data in ld_airquality_20190323.csv
# No data in ld_airquality_20190324.csv
# No data in ld_airquality_20190325.csv
# No data in ld_airquality_20190326.csv
# No data in ld_airquality_20190327.csv
# No data in ld_airquality_20190328.csv
# No data in ld_airquality_20190329.csv
# No data in ld_airquality_20190330.csv
# No data in ld_airquality_20190331.csv
# No data in ld_airquality_20190401.csv
# No data in ld_airquality_20190402.csv
# No data in ld_airquality_20190403.csv
# No data in ld_airquality_20190404.csv
# No data in ld_airquality_20190405.csv
# No data in ld_airquality_20190406.csv
# No data in ld_airquality_20190407.csv
# No data in ld_airquality_20190408.csv
# No data in ld_airquality_20190409.csv
# No data in ld_airquality_20190410.csv
# No data in ld_airquality_20190411.csv
# No data in ld_airquality_20190412.csv
# No data in ld_airquality_20190413.csv
# No data in ld_airquality_20190414.csv
# No data in ld_airquality_20190415.csv
# No data in ld_airquality_20190416.csv
# No data in ld_airquality_20190417.csv
# No data in ld_airquality_20190418.csv
# No data in ld_airquality_20190419.csv
# No data in ld_airquality_20190420.csv
# No data in ld_airquality_20190421.csv
# No data in ld_airquality_20190422.csv
# No data in ld_airquality_20190423.csv
# No data in ld_airquality_20190424.csv
# No data in ld_airquality_20190425.csv
# No data in ld_airquality_20190426.csv
# No data in ld_airquality_20190427.csv
# No data in ld_airquality_20190428.csv
# Air Quality in London: Done
# ../raw_data/london/grid/ld_grid_20180331.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180401.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180402.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180403.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180404.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180405.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180406.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180407.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180408.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180409.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180410.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180411.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180412.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180413.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180414.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180415.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180416.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180417.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180418.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180419.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180420.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180421.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180422.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180423.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180424.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180425.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180426.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180427.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180428.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180429.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180430.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180501.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180502.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180503.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180504.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180505.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180506.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180507.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180508.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180509.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180510.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180511.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180512.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180513.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180514.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180515.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180516.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180517.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180518.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180519.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180520.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180521.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180522.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180523.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180524.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180525.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180526.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180527.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180528.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180529.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180530.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180531.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180601.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180602.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180603.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180604.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180605.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180606.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180607.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180608.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180609.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180610.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180611.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180612.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180613.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180614.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180615.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180616.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180617.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180618.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180619.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180620.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180621.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180622.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180623.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180624.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180625.csv: Retrieved
# ../raw_data/london/grid/ld_grid_20180626.csv: Retrieved
# No data in ld_grid_20180627.csv
# No data in ld_grid_20180628.csv
# No data in ld_grid_20180629.csv
# No data in ld_grid_20180630.csv
# No data in ld_grid_20180701.csv
# No data in ld_grid_20180702.csv
# No data in ld_grid_20180703.csv
# No data in ld_grid_20180704.csv
# No data in ld_grid_20180705.csv
# No data in ld_grid_20180706.csv
# No data in ld_grid_20180707.csv
# No data in ld_grid_20180708.csv
# No data in ld_grid_20180709.csv
# No data in ld_grid_20180710.csv
# No data in ld_grid_20180711.csv
# No data in ld_grid_20180712.csv
# No data in ld_grid_20180713.csv
# No data in ld_grid_20180714.csv
# No data in ld_grid_20180715.csv
# No data in ld_grid_20180716.csv
# No data in ld_grid_20180717.csv
# No data in ld_grid_20180718.csv
# No data in ld_grid_20180719.csv
# No data in ld_grid_20180720.csv
# No data in ld_grid_20180721.csv
# No data in ld_grid_20180722.csv
# No data in ld_grid_20180723.csv
# No data in ld_grid_20180724.csv
# No data in ld_grid_20180725.csv
# No data in ld_grid_20180726.csv
# No data in ld_grid_20180727.csv
# No data in ld_grid_20180728.csv
# No data in ld_grid_20180729.csv
# No data in ld_grid_20180730.csv
# No data in ld_grid_20180731.csv
# No data in ld_grid_20180801.csv
# No data in ld_grid_20180802.csv
# No data in ld_grid_20180803.csv
# No data in ld_grid_20180804.csv
# No data in ld_grid_20180805.csv
# No data in ld_grid_20180806.csv
# No data in ld_grid_20180807.csv
# No data in ld_grid_20180808.csv
# No data in ld_grid_20180809.csv
# No data in ld_grid_20180810.csv
# No data in ld_grid_20180811.csv
# No data in ld_grid_20180812.csv
# No data in ld_grid_20180813.csv
# No data in ld_grid_20180814.csv
# No data in ld_grid_20180815.csv
# No data in ld_grid_20180816.csv
# No data in ld_grid_20180817.csv
# No data in ld_grid_20180818.csv
# No data in ld_grid_20180819.csv
# No data in ld_grid_20180820.csv
# No data in ld_grid_20180821.csv
# No data in ld_grid_20180822.csv
# No data in ld_grid_20180823.csv
# No data in ld_grid_20180824.csv
# No data in ld_grid_20180825.csv
# No data in ld_grid_20180826.csv
# No data in ld_grid_20180827.csv
# No data in ld_grid_20180828.csv
# No data in ld_grid_20180829.csv
# No data in ld_grid_20180830.csv
# No data in ld_grid_20180831.csv
# No data in ld_grid_20180901.csv
# No data in ld_grid_20180902.csv
# No data in ld_grid_20180903.csv
# No data in ld_grid_20180904.csv
# No data in ld_grid_20180905.csv
# No data in ld_grid_20180906.csv
# No data in ld_grid_20180907.csv
# No data in ld_grid_20180908.csv
# No data in ld_grid_20180909.csv
# No data in ld_grid_20180910.csv
# No data in ld_grid_20180911.csv
# No data in ld_grid_20180912.csv
# No data in ld_grid_20180913.csv
# No data in ld_grid_20180914.csv
# No data in ld_grid_20180915.csv
# No data in ld_grid_20180916.csv
# No data in ld_grid_20180917.csv
# No data in ld_grid_20180918.csv
# No data in ld_grid_20180919.csv
# No data in ld_grid_20180920.csv
# No data in ld_grid_20180921.csv
# No data in ld_grid_20180922.csv
# No data in ld_grid_20180923.csv
# No data in ld_grid_20180924.csv
# No data in ld_grid_20180925.csv
# No data in ld_grid_20180926.csv
# No data in ld_grid_20180927.csv
# No data in ld_grid_20180928.csv
# No data in ld_grid_20180929.csv
# No data in ld_grid_20180930.csv
# No data in ld_grid_20181001.csv
# No data in ld_grid_20181002.csv
# No data in ld_grid_20181003.csv
# No data in ld_grid_20181004.csv
# No data in ld_grid_20181005.csv
# No data in ld_grid_20181006.csv
# No data in ld_grid_20181007.csv
# No data in ld_grid_20181008.csv
# No data in ld_grid_20181009.csv
# No data in ld_grid_20181010.csv
# No data in ld_grid_20181011.csv
# No data in ld_grid_20181012.csv
# No data in ld_grid_20181013.csv
# No data in ld_grid_20181014.csv
# No data in ld_grid_20181015.csv
# No data in ld_grid_20181016.csv
# No data in ld_grid_20181017.csv
# No data in ld_grid_20181018.csv
# No data in ld_grid_20181019.csv
# No data in ld_grid_20181020.csv
# No data in ld_grid_20181021.csv
# No data in ld_grid_20181022.csv
# No data in ld_grid_20181023.csv
# No data in ld_grid_20181024.csv
# No data in ld_grid_20181025.csv
# No data in ld_grid_20181026.csv
# No data in ld_grid_20181027.csv
# No data in ld_grid_20181028.csv
# No data in ld_grid_20181029.csv
# No data in ld_grid_20181030.csv
# No data in ld_grid_20181031.csv
# No data in ld_grid_20181101.csv
# No data in ld_grid_20181102.csv
# No data in ld_grid_20181103.csv
# No data in ld_grid_20181104.csv
# No data in ld_grid_20181105.csv
# No data in ld_grid_20181106.csv
# No data in ld_grid_20181107.csv
# No data in ld_grid_20181108.csv
# No data in ld_grid_20181109.csv
# No data in ld_grid_20181110.csv
# No data in ld_grid_20181111.csv
# No data in ld_grid_20181112.csv
# No data in ld_grid_20181113.csv
# No data in ld_grid_20181114.csv
# No data in ld_grid_20181115.csv
# No data in ld_grid_20181116.csv
# No data in ld_grid_20181117.csv
# No data in ld_grid_20181118.csv
# No data in ld_grid_20181119.csv
# No data in ld_grid_20181120.csv
# No data in ld_grid_20181121.csv
# No data in ld_grid_20181122.csv
# No data in ld_grid_20181123.csv
# No data in ld_grid_20181124.csv
# No data in ld_grid_20181125.csv
# No data in ld_grid_20181126.csv
# No data in ld_grid_20181127.csv
# No data in ld_grid_20181128.csv
# No data in ld_grid_20181129.csv
# No data in ld_grid_20181130.csv
# No data in ld_grid_20181201.csv
# No data in ld_grid_20181202.csv
# No data in ld_grid_20181203.csv
# No data in ld_grid_20181204.csv
# No data in ld_grid_20181205.csv
# No data in ld_grid_20181206.csv
# No data in ld_grid_20181207.csv
# No data in ld_grid_20181208.csv
# No data in ld_grid_20181209.csv
# No data in ld_grid_20181210.csv
# No data in ld_grid_20181211.csv
# No data in ld_grid_20181212.csv
# No data in ld_grid_20181213.csv
# No data in ld_grid_20181214.csv
# No data in ld_grid_20181215.csv
# No data in ld_grid_20181216.csv
# No data in ld_grid_20181217.csv
# No data in ld_grid_20181218.csv
# No data in ld_grid_20181219.csv
# No data in ld_grid_20181220.csv
# No data in ld_grid_20181221.csv
# No data in ld_grid_20181222.csv
# No data in ld_grid_20181223.csv
# No data in ld_grid_20181224.csv
# No data in ld_grid_20181225.csv
# No data in ld_grid_20181226.csv
# No data in ld_grid_20181227.csv
# No data in ld_grid_20181228.csv
# No data in ld_grid_20181229.csv
# No data in ld_grid_20181230.csv
# No data in ld_grid_20181231.csv
# No data in ld_grid_20190101.csv
# No data in ld_grid_20190102.csv
# No data in ld_grid_20190103.csv
# No data in ld_grid_20190104.csv
# No data in ld_grid_20190105.csv
# No data in ld_grid_20190106.csv
# No data in ld_grid_20190107.csv
# No data in ld_grid_20190108.csv
# No data in ld_grid_20190109.csv
# No data in ld_grid_20190110.csv
# No data in ld_grid_20190111.csv
# No data in ld_grid_20190112.csv
# No data in ld_grid_20190113.csv
# No data in ld_grid_20190114.csv
# No data in ld_grid_20190115.csv
# No data in ld_grid_20190116.csv
# No data in ld_grid_20190117.csv
# No data in ld_grid_20190118.csv
# No data in ld_grid_20190119.csv
# No data in ld_grid_20190120.csv
# No data in ld_grid_20190121.csv
# No data in ld_grid_20190122.csv
# No data in ld_grid_20190123.csv
# No data in ld_grid_20190124.csv
# No data in ld_grid_20190125.csv
# No data in ld_grid_20190126.csv
# No data in ld_grid_20190127.csv
# No data in ld_grid_20190128.csv
# No data in ld_grid_20190129.csv
# No data in ld_grid_20190130.csv
# No data in ld_grid_20190131.csv
# No data in ld_grid_20190201.csv
# No data in ld_grid_20190202.csv
# No data in ld_grid_20190203.csv
# No data in ld_grid_20190204.csv
# No data in ld_grid_20190205.csv
# No data in ld_grid_20190206.csv
# No data in ld_grid_20190207.csv
# No data in ld_grid_20190208.csv
# No data in ld_grid_20190209.csv
# No data in ld_grid_20190210.csv
# No data in ld_grid_20190211.csv
# No data in ld_grid_20190212.csv
# No data in ld_grid_20190213.csv
# No data in ld_grid_20190214.csv
# No data in ld_grid_20190215.csv
# No data in ld_grid_20190216.csv
# No data in ld_grid_20190217.csv
# No data in ld_grid_20190218.csv
# No data in ld_grid_20190219.csv
# No data in ld_grid_20190220.csv
# No data in ld_grid_20190221.csv
# No data in ld_grid_20190222.csv
# No data in ld_grid_20190223.csv
# No data in ld_grid_20190224.csv
# No data in ld_grid_20190225.csv
# No data in ld_grid_20190226.csv
# No data in ld_grid_20190227.csv
# No data in ld_grid_20190228.csv
# No data in ld_grid_20190301.csv
# No data in ld_grid_20190302.csv
# No data in ld_grid_20190303.csv
# No data in ld_grid_20190304.csv
# No data in ld_grid_20190305.csv
# No data in ld_grid_20190306.csv
# No data in ld_grid_20190307.csv
# No data in ld_grid_20190308.csv
# No data in ld_grid_20190309.csv
# No data in ld_grid_20190310.csv
# No data in ld_grid_20190311.csv
# No data in ld_grid_20190312.csv
# No data in ld_grid_20190313.csv
# No data in ld_grid_20190314.csv
# No data in ld_grid_20190315.csv
# No data in ld_grid_20190316.csv
# No data in ld_grid_20190317.csv
# No data in ld_grid_20190318.csv
# No data in ld_grid_20190319.csv
# No data in ld_grid_20190320.csv
# No data in ld_grid_20190321.csv
# No data in ld_grid_20190322.csv
# No data in ld_grid_20190323.csv
# No data in ld_grid_20190324.csv
# No data in ld_grid_20190325.csv
# No data in ld_grid_20190326.csv
# No data in ld_grid_20190327.csv
# No data in ld_grid_20190328.csv
# No data in ld_grid_20190329.csv
# No data in ld_grid_20190330.csv
# No data in ld_grid_20190331.csv
# No data in ld_grid_20190401.csv
# No data in ld_grid_20190402.csv
# No data in ld_grid_20190403.csv
# No data in ld_grid_20190404.csv
# No data in ld_grid_20190405.csv
# No data in ld_grid_20190406.csv
# No data in ld_grid_20190407.csv
# No data in ld_grid_20190408.csv
# No data in ld_grid_20190409.csv
# No data in ld_grid_20190410.csv
# No data in ld_grid_20190411.csv
# No data in ld_grid_20190412.csv
# No data in ld_grid_20190413.csv
# No data in ld_grid_20190414.csv
# No data in ld_grid_20190415.csv
# No data in ld_grid_20190416.csv
# No data in ld_grid_20190417.csv
# No data in ld_grid_20190418.csv
# No data in ld_grid_20190419.csv
# No data in ld_grid_20190420.csv
# No data in ld_grid_20190421.csv
# No data in ld_grid_20190422.csv
# No data in ld_grid_20190423.csv
# No data in ld_grid_20190424.csv
# No data in ld_grid_20190425.csv
# No data in ld_grid_20190426.csv
# No data in ld_grid_20190427.csv
# No data in ld_grid_20190428.csv
# Grid Meteorology in London: Done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0d189422e017> in <module>()
#       6
#       7 end = time.time()
# ----> 8 print('Data Retrieval Time: {:.2f} secs'.format(end-start))
#
# NameError: name 'start' is not defined

# %%
from glob import glob

def read_multiple_csv(path, col = None, parse_dates = None):

    # glob(path+'/*'): return a list, which consist of each files in path
    # tqdm is a package which shows the progressive bar on Pythton CLI
    if parse_dates == None:
        if col is None:
            df = pd.concat([pd.read_csv(f) for f in sorted(glob(path+'/*'))])
        else:
            df = pd.concat([pd.read_csv(f)[col] for f in sorted(glob(path+'/*'))])
    else:
        if col is None:
            df = pd.concat([pd.read_csv(f, parse_dates = ['date'] ) for f in sorted(glob(path+'/*'))])
        else:
            df = pd.concat([pd.read_csv(f, parse_dates = ['date'] )[col] for f in sorted(glob(path+'/*'))])
    return df

# %%
stations = ['BL0', 'CD9', 'CD1', 'GN0', 'GR4', 'GN3', 'GR9', 'HV1', 'KF1', 'LW2', 'ST5', 'TH4', 'MY7']

# Initialize a directory
path = '../input/london'
if not os.path.isdir(path):
    os.makedirs(path)

# %%
if not os.path.isfile('../input/ld/london_aq_hist_data_merged.csv.gz'):

    # Read official historical data from file
    hist_data = pd.read_csv('../raw_data/London_historical_aqi_forecast_stations_20180331.csv', index_col=0)
    hist_data.columns = ['utc_time', 'station_id', 'PM2.5', 'PM10', 'NO2']
    hist_data = hist_data.fillna(0).drop_duplicates()

    # Merge latitude and longitude data
    aq_stations = pd.read_csv('../raw_data/London_AirQuality_Stations.csv', index_col=0)
    hist_data = hist_data.join(aq_stations[['Latitude', 'Longitude']], on='station_id')
    hist_data = hist_data.rename(columns={'Latitude': 'latitude', 'Longitude': 'longitude'})
    hist_data = hist_data.reindex(columns=['station_id', 'utc_time', 'longitude', 'latitude', 'PM2.5', 'PM10', 'NO2'])

    # Save the file
    hist_data.to_csv('../input/london/london_aq_hist_data_merged.csv.gz', index=False, compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-376b0aa9eb38> in <module>()
#       2
#       3     # Read official historical data from file
# ----> 4     hist_data = pd.read_csv('../raw_data/London_historical_aqi_forecast_stations_20180331.csv', index_col=0)
#       5     hist_data.columns = ['utc_time', 'station_id', 'PM2.5', 'PM10', 'NO2']
#       6     hist_data = hist_data.fillna(0).drop_duplicates()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../raw_data/London_historical_aqi_forecast_stations_20180331.csv' does not exist
